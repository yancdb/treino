# %%
#1000
# Out:
# {'t': array([ 0. ,  0.1,  0.2, ..., 49.7, 49.8, 49.9], dtype=float32), 'K': array([0.08  , 0.08  , 0.08  , ..., 0.0836, 0.0836, 0.0836], dtype=float32), 'V': array([0.    , 0.    , 0.    , ..., 0.0756, 0.0756, 0.0756], dtype=float32), 'U': array([0. , 0. , 0. , ..., 0.9, 0.9, 0.9], dtype=float32), 'true_x1': array([ 0.        ,  0.08      ,  0.136448  , ..., -0.04581441,
#        -0.04237468, -0.03894801], dtype=float32), 'true_w': array([0.        , 0.        , 0.00032   , ..., 0.10152074, 0.09971315,
#        0.09794825], dtype=float32), 'pred_x1': array([ 0.00428918,  0.06119478,  0.11523169, ..., -0.05712156,
#        -0.06028949, -0.05742709], dtype=float32), 'pred_w': array([ 1.6172715e-03,  4.0671602e-04, -2.4497509e-05, ...,
#         1.1297315e-01,  1.1111549e-01,  1.1048970e-01], dtype=float32)}
# (500000,)
# max err region:  0.08160000294446945 0.20000000298023224 0.05040000006556511 43.5
# max err 1.149413138628006
# mean err 0.0013391612282074449
# a 1000
# (500000,)
# ...

# %%
#2000
# Out:
# {'t': array([ 0. ,  0.1,  0.2, ..., 49.7, 49.8, 49.9], dtype=float32), 'K': array([0.08  , 0.08  , 0.08  , ..., 0.0836, 0.0836, 0.0836], dtype=float32), 'V': array([0.    , 0.    , 0.    , ..., 0.0756, 0.0756, 0.0756], dtype=float32), 'U': array([0. , 0. , 0. , ..., 0.9, 0.9, 0.9], dtype=float32), 'true_x1': array([ 0.        ,  0.08      ,  0.136448  , ..., -0.04581441,
#        -0.04237468, -0.03894801], dtype=float32), 'true_w': array([0.        , 0.        , 0.00032   , ..., 0.10152074, 0.09971315,
#        0.09794825], dtype=float32), 'pred_x1': array([ 0.00427023,  0.06306255,  0.11815347, ..., -0.05900072,
#        -0.06248708, -0.06406133], dtype=float32), 'pred_w': array([0.00131845, 0.00067192, 0.00023623, ..., 0.09648791, 0.09285019,
#        0.09073574], dtype=float32)}
# (500000,)
# max err region:  0.08160000294446945 0.20000000298023224 0.05040000006556511 23.399999618530273
# max err 1.066848079673946
# mean err 0.001216530903441405
# a 1000
# (500000,)
# ...

# %%
#4000
# Out:
# {'t': array([ 0. ,  0.1,  0.2, ..., 49.7, 49.8, 49.9], dtype=float32), 'K': array([0.08  , 0.08  , 0.08  , ..., 0.0836, 0.0836, 0.0836], dtype=float32), 'V': array([0.    , 0.    , 0.    , ..., 0.0756, 0.0756, 0.0756], dtype=float32), 'U': array([0. , 0. , 0. , ..., 0.9, 0.9, 0.9], dtype=float32), 'true_x1': array([ 0.        ,  0.08      ,  0.136448  , ..., -0.04581441,
#        -0.04237468, -0.03894801], dtype=float32), 'true_w': array([0.        , 0.        , 0.00032   , ..., 0.10152074, 0.09971315,
#        0.09794825], dtype=float32), 'pred_x1': array([-7.9102814e-05,  5.9684090e-02,  1.1483882e-01, ...,
#        -5.4440148e-02, -5.4800116e-02, -5.2741073e-02], dtype=float32), 'pred_w': array([0.00416407, 0.0016063 , 0.00080092, ..., 0.10137773, 0.10062636,
#        0.09876414], dtype=float32)}
# (500000,)
# max err region:  0.08160000294446945 0.20000000298023224 0.05040000006556511 23.0
# max err 0.8777663568034768
# mean err 0.002415653619376516
# a 1000
# (500000,)
# ...
