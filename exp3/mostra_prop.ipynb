# %%
# Out:
# {'t': array([ 0. ,  0.1,  0.2, ..., 49.7, 49.8, 49.9], dtype=float32), 'K': array([0.08  , 0.08  , 0.08  , ..., 0.0836, 0.0836, 0.0836], dtype=float32), 'V': array([0.    , 0.    , 0.    , ..., 0.0756, 0.0756, 0.0756], dtype=float32), 'U': array([0. , 0. , 0. , ..., 0.9, 0.9, 0.9], dtype=float32), 'true_x1': array([ 0.        ,  0.08      ,  0.136448  , ..., -0.04581441,
#        -0.04237468, -0.03894801], dtype=float32), 'true_w': array([0.        , 0.        , 0.00032   , ..., 0.10152074, 0.09971315,
#        0.09794825], dtype=float32), 'pred_x1': array([ 0.00220744,  0.06057627,  0.11651401, ..., -0.04897831,
#        -0.04656221, -0.04378998], dtype=float32), 'pred_w': array([0.00012578, 0.00112401, 0.00155054, ..., 0.09855281, 0.09612101,
#        0.09286933], dtype=float32)}
# (500000,)
# max err region:  0.08160000294446945 0.20000000298023224 0.05040000006556511 23.100000381469727
# max err 1.0765135260298848
# mean err 0.0013822911522514579
# a 1000
# (500000,)
# ...

# %%
# Out:
# {'t': array([ 0. ,  0.1,  0.2, ..., 49.7, 49.8, 49.9], dtype=float32), 'K': array([0.08  , 0.08  , 0.08  , ..., 0.0836, 0.0836, 0.0836], dtype=float32), 'V': array([0.    , 0.    , 0.    , ..., 0.0756, 0.0756, 0.0756], dtype=float32), 'U': array([0. , 0. , 0. , ..., 0.9, 0.9, 0.9], dtype=float32), 'true_x1': array([ 0.        ,  0.08      ,  0.136448  , ..., -0.04581441,
#        -0.04237468, -0.03894801], dtype=float32), 'true_w': array([0.        , 0.        , 0.00032   , ..., 0.10152074, 0.09971315,
#        0.09794825], dtype=float32), 'pred_x1': array([ 0.00221603,  0.06038807,  0.11641805, ..., -0.05164139,
#        -0.04845457, -0.04594459], dtype=float32), 'pred_w': array([-2.8781593e-05,  1.1223480e-03,  1.5399233e-03, ...,
#         9.8027095e-02,  9.5732644e-02,  9.3495257e-02], dtype=float32)}
# (500000,)
# max err region:  0.08160000294446945 0.20000000298023224 0.05040000006556511 22.399999618530273
# max err 1.0435539558529854
# mean err 0.0013112113907910344
# a 1000
# ...
