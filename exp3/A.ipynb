# %%
##E1
# Out:
# {'t': array([0.000e+00, 1.000e-02, 2.000e-02, ..., 4.997e+01, 4.998e+01,
#        4.999e+01], dtype=float32), 'K': array([0.08 , 0.08 , 0.08 , ..., 0.089, 0.089, 0.089], dtype=float32), 'V': array([0.   , 0.   , 0.   , ..., 0.114, 0.114, 0.114], dtype=float32), 'U': array([0. , 0. , 0. , ..., 0.9, 0.9, 0.9], dtype=float32), 'true_x1': array([0.        , 0.008     , 0.01568891, ..., 0.07337812, 0.07371826,
#        0.07405846], dtype=float32), 'true_w': array([0.0000000e+00, 0.0000000e+00, 3.2000000e-06, ..., 6.3390344e-02,
#        6.3318267e-02, 6.3246451e-02], dtype=float32), 'pred_x1': array([0.00146632, 0.00767086, 0.01392313, ..., 0.07662185, 0.07634117,
#        0.07749208], dtype=float32), 'pred_w': array([0.00218579, 0.00229654, 0.00232196, ..., 0.06653344, 0.06661533,
#        0.06641939], dtype=float32)}
# (10000000,)
# max err region:  0.0860000029206276 0.20000000298023224 0.05400000140070915 44.20000076293945
# max err 0.3022388517856598
# ...

# %%
# Out:
# {'t': array([0.000e+00, 1.000e-02, 2.000e-02, ..., 4.997e+01, 4.998e+01,
#        4.999e+01], dtype=float32), 'K': array([0.08 , 0.08 , 0.08 , ..., 0.089, 0.089, 0.089], dtype=float32), 'V': array([0.   , 0.   , 0.   , ..., 0.114, 0.114, 0.114], dtype=float32), 'U': array([0. , 0. , 0. , ..., 0.9, 0.9, 0.9], dtype=float32), 'true_x1': array([0.        , 0.008     , 0.01568891, ..., 0.07337812, 0.07371826,
#        0.07405846], dtype=float32), 'true_w': array([0.0000000e+00, 0.0000000e+00, 3.2000000e-06, ..., 6.3390344e-02,
#        6.3318267e-02, 6.3246451e-02], dtype=float32), 'pred_x1': array([0.00138875, 0.00698702, 0.01256357, ..., 0.07565583, 0.07509938,
#        0.07602328], dtype=float32), 'pred_w': array([0.00118988, 0.00131116, 0.00148128, ..., 0.06603612, 0.06613192,
#        0.06595685], dtype=float32)}
# (10000000,)
# max err region:  0.08699999749660492 0.30000001192092896 0.06599999964237213 49.9900016784668
# max err 0.3761870861053467
# mean err 0.0001839668343767687
# ...
