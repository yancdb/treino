# %%
##Todas as constraints
# Out:
# {'t': array([ 0. ,  0.1,  0.2, ..., 49.7, 49.8, 49.9], dtype=float32), 'K': array([0.08  , 0.08  , 0.08  , ..., 0.0836, 0.0836, 0.0836], dtype=float32), 'V': array([0.    , 0.    , 0.    , ..., 0.0756, 0.0756, 0.0756], dtype=float32), 'U': array([0. , 0. , 0. , ..., 0.9, 0.9, 0.9], dtype=float32), 'true_x1': array([ 0.        ,  0.08      ,  0.136448  , ..., -0.04581441,
#        -0.04237468, -0.03894801], dtype=float32), 'true_w': array([0.        , 0.        , 0.00032   , ..., 0.10152074, 0.09971315,
#        0.09794825], dtype=float32), 'pred_x1': array([ 0.00382703,  0.06761456,  0.1204774 , ..., -0.05588503,
#        -0.05496866, -0.05553259], dtype=float32), 'pred_w': array([0.00387449, 0.00229214, 0.00025566, ..., 0.10075115, 0.0997386 ,
#        0.09861201], dtype=float32)}
# (500000,)
# max err region:  0.08160000294446945 0.20000000298023224 0.05040000006556511 22.5
# max err 1.1327780708670616
# mean err 0.001177240618405437
# a 1000
# (500000,)
# IAPP 0.07999999821186066
# ...

# %%
#So data, ambas
# Out:
# {'t': array([ 0. ,  0.1,  0.2, ..., 49.7, 49.8, 49.9], dtype=float32), 'K': array([0.08  , 0.08  , 0.08  , ..., 0.0836, 0.0836, 0.0836], dtype=float32), 'V': array([0.    , 0.    , 0.    , ..., 0.0756, 0.0756, 0.0756], dtype=float32), 'U': array([0. , 0. , 0. , ..., 0.9, 0.9, 0.9], dtype=float32), 'true_x1': array([ 0.        ,  0.08      ,  0.136448  , ..., -0.04581441,
#        -0.04237468, -0.03894801], dtype=float32), 'true_w': array([0.        , 0.        , 0.00032   , ..., 0.10152074, 0.09971315,
#        0.09794825], dtype=float32), 'pred_x1': array([ 0.01095994,  0.06150565,  0.11717543, ..., -0.04663447,
#        -0.04658671, -0.05007271], dtype=float32), 'pred_w': array([6.7287683e-04, 1.3305619e-04, 3.5349280e-05, ..., 9.8253354e-02,
#        9.7831413e-02, 9.3090773e-02], dtype=float32)}
# (500000,)
# max err region:  0.08160000294446945 0.20000000298023224 0.05040000006556511 22.100000381469727
# max err 0.9925150536000729
# mean err 0.001845766367559826
# a 1000
# ...

# %%
#So data sem c2

# %%
# Out:
# {'t': array([ 0. ,  0.1,  0.2, ..., 49.7, 49.8, 49.9], dtype=float32), 'K': array([0.08  , 0.08  , 0.08  , ..., 0.0836, 0.0836, 0.0836], dtype=float32), 'V': array([0.    , 0.    , 0.    , ..., 0.0756, 0.0756, 0.0756], dtype=float32), 'U': array([0. , 0. , 0. , ..., 0.9, 0.9, 0.9], dtype=float32), 'true_x1': array([ 0.        ,  0.08      ,  0.136448  , ..., -0.04581441,
#        -0.04237468, -0.03894801], dtype=float32), 'true_w': array([0.        , 0.        , 0.00032   , ..., 0.10152074, 0.09971315,
#        0.09794825], dtype=float32), 'pred_x1': array([ 0.01866773,  0.06488536,  0.11477032, ..., -0.04075876,
#        -0.0383473 , -0.03506314], dtype=float32), 'pred_w': array([0.0051257 , 0.00377822, 0.00315763, ..., 0.10119298, 0.0994456 ,
#        0.09710379], dtype=float32)}
# (500000,)
# max err region:  0.08160000294446945 0.20000000298023224 0.05040000006556511 22.299999237060547
# max err 1.0600713193416595
# mean err 0.00034625843025142526
# a 1000
# (500000,)
# ...
